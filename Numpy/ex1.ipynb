# %% [markdown]
# ## what is Avg Height of US presidents?

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('president_heights.csv')
heights = np.array(data['height(cm)'])

# %% [markdown]
# ### summary statistics:

# %%
print(f"Total president is {heights.size}")
print(f"mean presidents is {heights.mean()}")
print(f"std presidents is {heights.std()}")
print(f"min presidents is {heights.min()}")
print(f"max presidents is {heights.max()}")
# Out:
# Total president is 44
# mean presidents is 180.04545454545453
# std presidents is 6.983599441335736
# min presidents is 163
# max presidents is 193

# %% [markdown]
# ### quantiles:

# %%
print("25th percentile:   ", np.percentile(heights, 25))
print("Median:            ", np.median(heights))
print("75th percentile:   ", np.percentile(heights, 75))
# Out:
# 25th percentile:    174.75
# Median:             182.0
# 75th percentile:    183.5

# %% [markdown]
# ### visual representation of heights:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn ;seaborn.set_theme()

plt.hist(heights)
plt.title('Height Distribution of US Presidents')
plt.xlabel('height (cm)')
plt.ylabel('number')
plt.show()
